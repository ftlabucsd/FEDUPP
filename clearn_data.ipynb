# %%
import pandas as pd
import paths

# %%
ctrl = paths.reversal_veh
ctrl
# Out:
# ['/Users/yaomingyang/Desktop/FED3-data/behavior data integrated/mPFC/Vehicle Tx/Reversal/M10.CSV',
#  '/Users/yaomingyang/Desktop/FED3-data/behavior data integrated/mPFC/Vehicle Tx/Reversal/M6.csv',
#  '/Users/yaomingyang/Desktop/FED3-data/behavior data integrated/mPFC/Vehicle Tx/Reversal/M7.CSV',
#  '/Users/yaomingyang/Desktop/FED3-data/behavior data integrated/mPFC/Vehicle Tx/Reversal/M8.CSV',
#  '/Users/yaomingyang/Desktop/FED3-data/behavior data integrated/mPFC/Vehicle Tx/Reversal/M9.CSV']

# %%
print(ctrl[-2])
df = pd.read_csv(ctrl[-2])
df = df[:1083]
df.tail(10)
# Out:
# /Users/yaomingyang/Desktop/FED3-data/behavior data integrated/mPFC/Vehicle Tx/Reversal/M8.CSV
#      MM:DD:YYYY hh:mm:ss Library_Version Session_type  Device_Number  \
# 1073   5/1/2024 11:14:08          1.16.3       RevT_R              0
# 1074   5/1/2024 11:14:11          1.16.3       RevT_R              0
# 1075   5/1/2024 11:14:45          1.16.3       RevT_R              0
# 1076   5/1/2024 11:15:51          1.16.3       RevT_R              0
# 1077   5/1/2024 11:16:26          1.16.3       RevT_R              0
# 1078   5/1/2024 11:16:34          1.16.3       RevT_R              0
# 1079   5/1/2024 11:16:41          1.16.3       RevT_R              0
# 1080   5/1/2024 11:18:50          1.16.3       RevT_R              0
# 1081   5/1/2024 11:22:52          1.16.3       RevT_R              0
# 1082   5/1/2024 11:23:17          1.16.3       RevT_R              0
#
#       Battery_Voltage  Motor_Turns  FR                Event Active_Poke  \
# ...

# %%
df.to_csv(ctrl[-2], index=False)
