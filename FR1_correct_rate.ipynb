# %% [markdown]
# ## FR1 Correct Rate

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import meals as ml
import intervals as invs
import numpy as np

# %% [markdown]
# #### Define preprocess function for read excel

# %%
def read_excel_by_sheet(sheet, parent='../behavior data integrated/Adjusted FED3 Data.xlsx'):
    df = pd.read_excel(parent, sheet_name=sheet)

    df = df[['MM:DD:YYYY hh:mm:ss', 'Event', 'Active_Poke',
         'Cum_Sum', 'Percent_Correct']].rename(columns={'MM:DD:YYYY hh:mm:ss': 'Time'}).fillna(0)
    
    df['Percent_Correct'] *= 100
    df['Time'] = pd.to_datetime(df['Time'])
    mask = (df['Percent_Correct'] != 0) & (df['Cum_Sum'] != 0)
    df = df[mask]
    
    return df

# %%
ctrl_ending_corr = []
cask_ending_corr = []

# %%
ctrl_dict_corr = {}
cask_dict_corr = {}

# %% [markdown]
# ## Control Group

# %% [markdown]
# ###  Bhv 2

# %%
B2M1 = read_excel_by_sheet(sheet='B2.M2')
B2M2 = read_excel_by_sheet(sheet='B2.M3')
B2M3 = read_excel_by_sheet(sheet='B2.M4')

# %%
ctrl_ending_corr.append(B2M1['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B2M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B2M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B2M1'] = B2M1['Percent_Correct'].tail(1).values[0]
ctrl_dict_corr['B2M2'] = (B2M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B2M3'] = (B2M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr
# Out:
# {'B2M1': 55.05882352941176,
#  'B2M2': 65.32258064516128,
#  'B2M3': 64.23357664233576}

# %% [markdown]
# ### Learning Rate for Bhv 2

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B2M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B2M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B2M3, x='Time', y='Percent_Correct', label='M3')

plt.grid()
plt.title('Changes in Correction Rate for Control Group 2', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.yticks(range(0, 110, 10))
plt.legend()
legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %%
plt.figure(figsize=(15, 6), dpi=90)

sns.lineplot(data=B2M1, x='Time', y='Cum_Sum', label='M1')
sns.lineplot(data=B2M2, x='Time', y='Cum_Sum', label='M2')
sns.lineplot(data=B2M3, x='Time', y='Cum_Sum', label='M3')

plt.grid()
plt.title('Cumulative Sum of Pellet for Control Group 2', fontsize=22)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Cumulative Percentage', fontsize=16)
plt.legend()
legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ###  Bhv 3

# %%
B3M1 = read_excel_by_sheet(sheet='B3.M1')
B3M2 = read_excel_by_sheet(sheet='B3.M2')
B3M3 = read_excel_by_sheet(sheet='B3.M3')
B3M4 = read_excel_by_sheet(sheet='B3.M4')

# %%
ctrl_ending_corr.append(B3M1['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B3M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B3M3['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B3M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B3M1'] = B3M1['Percent_Correct'].tail(1).values[0]
ctrl_dict_corr['B3M2'] = (B3M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B3M3'] = (B3M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B3M4'] = (B3M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr
# Out:
# {'B2M1': 55.05882352941176,
#  'B2M2': 65.32258064516128,
#  'B2M3': 64.23357664233576,
#  'B3M1': 84.15841584158416,
#  'B3M2': 72.1938775510204,
#  'B3M3': 55.42725173210161,
#  'B3M4': 42.88025889967638}

# %% [markdown]
# ### Learning Rate for Bhv 3

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B3M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B3M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B3M3, x='Time', y='Percent_Correct', label='M3')
sns.lineplot(data=B3M4, x='Time', y='Percent_Correct', label='M4')

plt.grid()
plt.title('Changes in Correction Rate for Control Group 3', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.yticks(range(0, 110, 10))
plt.legend()
legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %%
plt.figure(figsize=(15, 6), dpi=90)

sns.lineplot(data=B3M1, x='Time', y='Cum_Sum', label='M1')
sns.lineplot(data=B3M2, x='Time', y='Cum_Sum', label='M2')
sns.lineplot(data=B3M3, x='Time', y='Cum_Sum', label='M3')
sns.lineplot(data=B3M4, x='Time', y='Cum_Sum', label='M4')

plt.grid()
plt.title('Cumulative Sum of Pellet for Control Group 3', fontsize=22)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Cumulative Percentage', fontsize=16)
plt.legend()
legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ###  Bhv 5

# %%
B5M1 = read_excel_by_sheet(sheet='B5.M1')
B5M2 = read_excel_by_sheet(sheet='B5.M2')
B5M3 = read_excel_by_sheet(sheet='B5.M3')
B5M4 = read_excel_by_sheet(sheet='B5.M4')

# %%
ctrl_ending_corr.append(B5M1['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B5M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B5M3['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B5M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B5M1'] = B5M1['Percent_Correct'].tail(1).values[0]
ctrl_dict_corr['B5M2'] = (B5M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B5M3'] = (B5M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B5M4'] = (B5M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr
# Out:
# {'B2M1': 55.05882352941176,
#  'B2M2': 65.32258064516128,
#  'B2M3': 64.23357664233576,
#  'B3M1': 84.15841584158416,
#  'B3M2': 72.1938775510204,
#  'B3M3': 55.42725173210161,
#  'B3M4': 42.88025889967638,
#  'B5M1': 62.272727272727266,
#  'B5M2': 79.16666666666666,
#  'B5M3': 80.13029315960912,
#  'B5M4': 70.23809523809523}

# %% [markdown]
# ### Learning Rate for Bhv 5

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B5M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B5M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B5M3, x='Time', y='Percent_Correct', label='M3')
sns.lineplot(data=B5M4, x='Time', y='Percent_Correct', label='M4')

plt.grid()
plt.title('Changes in Correction Rate for Control Group 5', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.yticks(range(0, 110, 10))
plt.legend()
legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ###  Bhv 7

# %%
B7M2 = read_excel_by_sheet(sheet='B7.M2')
B7M3 = read_excel_by_sheet(sheet='B7.M3')
B7M4 = read_excel_by_sheet(sheet='B7.M4')

# %%
ctrl_ending_corr.append(B7M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B7M3['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B7M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B7M2'] = (B7M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B7M3'] = (B7M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B7M4'] = (B7M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr
# Out:
# {'B2M1': 55.05882352941176,
#  'B2M2': 65.32258064516128,
#  'B2M3': 64.23357664233576,
#  'B3M1': 84.15841584158416,
#  'B3M2': 72.1938775510204,
#  'B3M3': 55.42725173210161,
#  'B3M4': 42.88025889967638,
#  'B5M1': 62.272727272727266,
#  'B5M2': 79.16666666666666,
#  'B5M3': 80.13029315960912,
#  'B5M4': 70.23809523809523,
#  'B7M2': 84.22939068100358,
#  'B7M3': 71.35922330097088,
#  'B7M4': 86.28048780487805}

# %% [markdown]
# ### Learning Rate for Bhv 7

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B7M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B7M3, x='Time', y='Percent_Correct', label='M3')
sns.lineplot(data=B7M4, x='Time', y='Percent_Correct', label='M4')

plt.grid()
plt.title('Changes in Correction Rate for Control Group 7', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.yticks(range(0, 110, 10))

plt.legend()
legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ## CASK Experimental Group

# %% [markdown]
# ###  Bhv 1

# %%
B1M1 = read_excel_by_sheet(sheet='B1.M1')
B1M2 = read_excel_by_sheet(sheet='B1.M2')
B1M3 = read_excel_by_sheet(sheet='B1.M3')

# %%
cask_ending_corr.append(B1M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B1M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B1M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B1M1'] = B1M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B1M2'] = (B1M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B1M3'] = (B1M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr
# Out:
# {'B1M1': 87.96296296296296,
#  'B1M2': 81.42857142857143,
#  'B1M3': 70.39274924471299}

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B1M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B1M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B1M3, x='Time', y='Percent_Correct', label='M3')

plt.grid()
plt.title('Changes in Correction Rate for CASK Group 1', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.legend()
plt.yticks(range(0, 110, 10))

legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ###  Bhv 4

# %%
B4M1 = read_excel_by_sheet(sheet='B4.M1')
B4M2 = read_excel_by_sheet(sheet='B4.M2')
B4M3 = read_excel_by_sheet(sheet='B4.M3')
B4M4 = read_excel_by_sheet(sheet='B4.M4')

# %%
cask_ending_corr.append(B4M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B4M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B4M3['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B4M4['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B4M1'] = B4M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B4M2'] = (B4M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B4M3'] = (B4M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B4M4'] = (B4M4['Percent_Correct'].tail(1).values[0])
cask_dict_corr
# Out:
# {'B1M1': 87.96296296296296,
#  'B1M2': 81.42857142857143,
#  'B1M3': 70.39274924471299,
#  'B4M1': 80.4635761589404,
#  'B4M2': 98.00443458980045,
#  'B4M3': 78.38983050847457,
#  'B4M4': 87.53709198813057}

# %% [markdown]
# ### Learning Rate for Bhv 4

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B4M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B4M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B4M3, x='Time', y='Percent_Correct', label='M3')
sns.lineplot(data=B4M4, x='Time', y='Percent_Correct', label='M4')

plt.grid()
plt.title('Changes in Correction Rate for CASK Group 4', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.yticks(range(0, 110, 10))
plt.legend()

legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ###  Bhv 6

# %%
B6M1 = read_excel_by_sheet(sheet='B6.M1')
B6M2 = read_excel_by_sheet(sheet='B6.M2')
B6M3 = read_excel_by_sheet(sheet='B6.M3')
B6M4 = read_excel_by_sheet(sheet='B6.M4')

# %%
cask_ending_corr.append(B6M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B6M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B6M3['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B6M4['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B6M1'] = B6M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B6M2'] = (B6M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B6M3'] = (B6M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B6M4'] = (B6M4['Percent_Correct'].tail(1).values[0])
cask_dict_corr
# Out:
# {'B1M1': 87.96296296296296,
#  'B1M2': 81.42857142857143,
#  'B1M3': 70.39274924471299,
#  'B4M1': 80.4635761589404,
#  'B4M2': 98.00443458980045,
#  'B4M3': 78.38983050847457,
#  'B4M4': 87.53709198813057,
#  'B6M1': 78.0327868852459,
#  'B6M2': 68.40796019900498,
#  'B6M3': 70.86614173228347,
#  'B6M4': 88.52459016393442}

# %% [markdown]
# ### Learning Rate for Bhv 6

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B6M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B6M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B6M3, x='Time', y='Percent_Correct', label='M3')
sns.lineplot(data=B6M4, x='Time', y='Percent_Correct', label='M4')

plt.grid()
plt.title('Changes in Correction Rate for CASK Group 6', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.yticks(range(0, 110, 10))

plt.legend()

legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ###  Bhv 8

# %%
B8M1 = read_excel_by_sheet(sheet='B8.M1')
B8M2 = read_excel_by_sheet(sheet='B8.M2')
B8M3 = read_excel_by_sheet(sheet='B8.M3')

# %%
cask_ending_corr.append(B8M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B8M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B8M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B8M1'] = B8M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B8M2'] = (B8M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B8M3'] = (B8M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr
# Out:
# {'B1M1': 87.96296296296296,
#  'B1M2': 81.42857142857143,
#  'B1M3': 70.39274924471299,
#  'B4M1': 80.4635761589404,
#  'B4M2': 98.00443458980045,
#  'B4M3': 78.38983050847457,
#  'B4M4': 87.53709198813057,
#  'B6M1': 78.0327868852459,
#  'B6M2': 68.40796019900498,
#  'B6M3': 70.86614173228347,
#  'B6M4': 88.52459016393442,
#  'B8M1': 92.25092250922509,
#  'B8M2': 74.75538160469667,
#  'B8M3': 90.17543859649123}

# %%
ctrl_dict_corr
cask_dict_corr

# %%
import csv

# %%
csv_file = 'control_accuracy.csv'

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(['Mice', 'Accuracy'])

    for key, value in ctrl_dict_corr.items():
        writer.writerow([key, value])

# %%
csv_file = 'cask_accuracy.csv'

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(['Mice', 'Accuracy'])

    for key, value in cask_dict_corr.items():
        writer.writerow([key, value])

# %% [markdown]
# ### Learning Rate for Bhv 8

# %%
plt.figure(figsize=(15, 6), dpi=90)
sns.lineplot(data=B8M1, x='Time', y='Percent_Correct', label='M1')
sns.lineplot(data=B8M2, x='Time', y='Percent_Correct', label='M2')
sns.lineplot(data=B8M3, x='Time', y='Percent_Correct', label='M3')

plt.grid()
plt.title('Changes in Correction Rate for CASK Group 8', fontsize=24)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Correct Rate', fontsize=16)
plt.legend()
plt.yticks(range(0, 110, 10))

legend = plt.legend(title='Mice', fontsize=10)
legend.get_title().set_fontsize(12)
plt.show()

# %% [markdown]
# ### Analysis

# %%
ctrl_ending_corr
# Out:
# [55.05882352941176,
#  65.32258064516128,
#  64.23357664233576,
#  84.15841584158416,
#  72.1938775510204,
#  55.42725173210161,
#  42.88025889967638,
#  62.272727272727266,
#  79.16666666666666,
#  80.13029315960912,
#  70.23809523809523,
#  84.22939068100358,
#  71.35922330097088,
#  86.28048780487805]

# %%
cask_ending_corr
# Out:
# [87.96296296296296,
#  81.42857142857143,
#  70.39274924471299,
#  80.4635761589404,
#  98.00443458980045,
#  78.38983050847457,
#  87.53709198813057,
#  78.0327868852459,
#  68.40796019900498,
#  70.86614173228347,
#  88.52459016393442,
#  92.25092250922509,
#  74.75538160469667,
#  90.17543859649123]

# %%
invs.perform_T_test(ctrl_ending_corr, cask_ending_corr)
# Out:
# P Value is  0.0064146427421453815
# There is a significant difference between the two groups.

# %%
invs.MannWhitneyUTest(ctrl_ending_corr, cask_ending_corr)
# Out:
# U Statistic: 43.0
# P-value: 0.012274648109661161
# There is a significant difference between the two groups.

# %%
ctrl_mean = np.mean(ctrl_ending_corr)
cask_mean = np.mean(cask_ending_corr)
ctrl_err = np.std(ctrl_ending_corr) / np.sqrt(len(ctrl_ending_corr))
cask_err = np.std(cask_ending_corr) / np.sqrt(len(cask_ending_corr))
groups = ['Control', 'CASK']

# %%
x = np.arange(len(groups))
width = 0.4

# %%
# Create the bar plot for averages
plt.figure(figsize=(7, 7))

plt.bar([1, 2], [ctrl_mean, cask_mean], yerr=[ctrl_err, cask_err], capsize=12, tick_label=groups, 
        width=width, color=['lightblue', 'yellow'], alpha=0.8, zorder=1, label=['Control', 'CASK'])

x1 = [1] * len(ctrl_ending_corr)
x2 = [2] * len(cask_ending_corr)
plt.scatter(x1, ctrl_ending_corr, marker='o', color='blue', zorder=2) 
plt.scatter(x2, cask_ending_corr, marker='x', color='orange', zorder=2)

plt.xlabel('Groups', fontsize=14)
plt.ylabel('Correct Rate (%)', fontsize=14)
plt.title('Average Correct Rate of Control and CASK Groups in FR1', fontsize=16)

plt.legend()
plt.show()

# %% [markdown]
# * Overall, mice in CASK Group has higher correct rate at the end of the session
# May do further analysis/stats test
