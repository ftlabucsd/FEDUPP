# %% [markdown]
# ## FR1 Correct Rate

# %%
import matplotlib.pyplot as plt
import intervals as invs
import numpy as np
import accuracy as acc
import paths
import pandas as pd

# %% [markdown]
# #### Define preprocess function for read excel

# %%
ctrl_ending_corr = []
cask_ending_corr = []
ctrl_dict_corr = {}
cask_dict_corr = {}

# %% [markdown]
# ## Control Group

# %% [markdown]
# ###  Bhv 2

# %%
B2M1 = acc.read_excel_by_sheet(sheet='B2.M2')
B2M2 = acc.read_excel_by_sheet(sheet='B2.M3')
B2M3 = acc.read_excel_by_sheet(sheet='B2.M4')
ctrl_ending_corr.append(B2M1['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B2M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B2M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B2M1'] = B2M1['Percent_Correct'].tail(1).values[0]
ctrl_dict_corr['B2M2'] = (B2M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B2M3'] = (B2M3['Percent_Correct'].tail(1).values[0])

# %% [markdown]
# ### Learning Rate for Bhv 2

# %%
acc.graph_cumulative_acc([B2M1, B2M2, B2M3], 2)

# %% [markdown]
# ###  Bhv 3

# %%
B3M1 = acc.read_excel_by_sheet(sheet='B3.M1')
B3M2 = acc.read_excel_by_sheet(sheet='B3.M2')
B3M3 = acc.read_excel_by_sheet(sheet='B3.M3')
B3M4 = acc.read_excel_by_sheet(sheet='B3.M4')

# %%
ctrl_ending_corr.append(B3M1['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B3M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B3M3['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B3M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B3M1'] = B3M1['Percent_Correct'].tail(1).values[0]
ctrl_dict_corr['B3M2'] = (B3M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B3M3'] = (B3M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B3M4'] = (B3M4['Percent_Correct'].tail(1).values[0])

# %% [markdown]
# ### Learning Rate for Bhv 3

# %%
acc.graph_cumulative_acc([B3M1, B3M2, B3M3, B3M4], 3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/kk/3lqkkjzx7kb59yj16vgzwnyh0000gn/T/ipykernel_34312/2005278086.py in ?()
# ----> 1 acc.graph_cumulative_acc([B3M1, B3M2, B3M3, B3M4], 3)
#
# ~/Documents/VS Code/lab/FED3-data/accuracy.py in ?(mice, group)
#      22      plt.figure(figsize=(15, 6), dpi=90)
#      23
#      24      cnt = 1
#      25      for each in mice:
# ---> 26           sns.lineplot(data=each, x='Time', y='Percent_Correct', label=f'M{cnt}')
#      27           cnt += 1
#      28      plt.grid()
#      29      plt.title(f'Changes in Correction Rate for Control Group {group}', fontsize=24)
#
# ~/anaconda3/lib/python3.10/site-packages/seaborn/relational.py in ?(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     503     # and we should probably do that here too
#     504     color = kwargs.pop("color", kwargs.pop("c", None))
#     505     kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
#     506
# --> 507     p.plot(ax, kwargs)
#     508     return ax
#
# ~/anaconda3/lib/python3.10/site-packages/seaborn/relational.py in ?(self, ax, kws)
#     288                     raise ValueError(err)
#     289                 grouped = sub_data.groupby(orient, sort=self.sort)
#     290                 # Could pass as_index=False instead of reset_index,
#     291                 # but that fails on a corner case with older pandas.
# --> 292                 sub_data = grouped.apply(agg, other).reset_index()
#     293             else:
#     294                 sub_data[f"{other}min"] = np.nan
#     295                 sub_data[f"{other}max"] = np.nan
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in ?(self, func, *args, **kwargs)
#    1763         # ignore SettingWithCopy here in case the user mutates
#    1764         with option_context("mode.chained_assignment", None):
#    1765             try:
#    1766                 result = self._python_apply_general(f, self._selected_obj)
# -> 1767             except TypeError:
#    1768                 # gh-20949
#    1769                 # try again, with .apply acting as a filtering
#    1770                 # operation, by excluding the grouping column
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in ?(self, f, data, not_indexed_same, is_transform, is_agg)
#    1811         -------
#    1812         Series or DataFrame
#    1813             data after applying f
#    1814         """
# -> 1815         values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1816         if not_indexed_same is None:
#    1817             not_indexed_same = mutated
#    1818
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/ops.py in ?(self, f, data, axis)
#     901             object.__setattr__(group, "name", key)
#     902
#     903             # group might be modified
#     904             group_axes = group.axes
# --> 905             res = f(group)
#     906             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     907                 mutated = True
#     908             result_values.append(res)
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in ?(g)
#    1752                 @wraps(func)
#    1753                 def f(g):
# -> 1754                     return func(g, *args, **kwargs)
#
# ~/anaconda3/lib/python3.10/site-packages/seaborn/_statistics.py in ?(self, data, var)
#     482     def __call__(self, data, var):
#     483         """Aggregate over `var` column of `data` with estimate and error interval."""
# --> 484         vals = data[var]
#     485         if callable(self.estimator):
#     486             # You would think we could pass to vals.agg, and yet:
#     487             # https://github.com/mwaskom/seaborn/issues/2943
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key)
#    3868                 self.columns.is_unique
#    3869                 and key in self.columns
#    3870                 or key in self.columns.drop_duplicates(keep=False)
#    3871             ):
# -> 3872                 return self._get_item_cache(key)
#    3873
#    3874             elif is_mi and self.columns.is_unique and key in self.columns:
#    3875                 return self._getitem_multilevel(key)
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, item)
#    4414             # All places that call _get_item_cache have unique columns,
#    4415             #  pending resolution of GH#33047
#    4416
#    4417             loc = self.columns.get_loc(item)
# -> 4418             res = self._ixs(loc, axis=1)
#    4419
#    4420             cache[item] = res
#    4421
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, i, axis)
#    3803         else:
#    3804             label = self.columns[i]
#    3805
#    3806             col_mgr = self._mgr.iget(i)
# -> 3807             result = self._box_col_values(col_mgr, i)
#    3808
#    3809             # this is a cached value, mark it so
#    3810             result._set_as_cached(label, self)
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, values, loc)
#    4393         name = self.columns[loc]
#    4394         # We get index=self.index bc values is a SingleDataManager
#    4395         obj = self._constructor_sliced_from_mgr(values, axes=values.axes)
#    4396         obj._name = name
# -> 4397         return obj.__finalize__(self)
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, other, method, **kwargs)
#    6171             for name in set(self._metadata) & set(other._metadata):
#    6172                 assert isinstance(name, str)
#    6173                 object.__setattr__(self, name, getattr(other, name, None))
#    6174
# -> 6175         if method == "concat":
#    6176             attrs = other.objs[0].attrs
#    6177             check_attrs = all(objs.attrs == attrs for objs in other.objs[1:])
#    6178             if check_attrs:
#
# KeyboardInterrupt:

# %% [markdown]
# ###  Bhv 5

# %%
B5M1 = acc.read_excel_by_sheet(sheet='B5.M1')
B5M2 = acc.read_excel_by_sheet(sheet='B5.M2')
B5M3 = acc.read_excel_by_sheet(sheet='B5.M3')
B5M4 = acc.read_excel_by_sheet(sheet='B5.M4')

# %%
ctrl_ending_corr.append(B5M1['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B5M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B5M3['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B5M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B5M1'] = B5M1['Percent_Correct'].tail(1).values[0]
ctrl_dict_corr['B5M2'] = (B5M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B5M3'] = (B5M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B5M4'] = (B5M4['Percent_Correct'].tail(1).values[0])

# %% [markdown]
# ### Learning Rate for Bhv 5

# %%
acc.graph_cumulative_acc([B5M1, B5M2, B5M3, B5M4], 5)

# %% [markdown]
# ###  Bhv 7

# %%
B7M2 = acc.read_excel_by_sheet(sheet='B7.M2')
B7M3 = acc.read_excel_by_sheet(sheet='B7.M3')
B7M4 = acc.read_excel_by_sheet(sheet='B7.M4')

# %%
ctrl_ending_corr.append(B7M2['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B7M3['Percent_Correct'].tail(1).values[0])
ctrl_ending_corr.append(B7M4['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B7M2'] = (B7M2['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B7M3'] = (B7M3['Percent_Correct'].tail(1).values[0])
ctrl_dict_corr['B7M4'] = (B7M4['Percent_Correct'].tail(1).values[0])

# %% [markdown]
# ### Learning Rate for Bhv 7

# %%
acc.graph_cumulative_acc([B7M2, B7M3, B7M4], 7)

# %% [markdown]
# ## CASK Experimental Group

# %% [markdown]
# ###  Bhv 1

# %%
B1M1 = acc.read_excel_by_sheet(sheet='B1.M1')
B1M2 = acc.read_excel_by_sheet(sheet='B1.M2')
B1M3 = acc.read_excel_by_sheet(sheet='B1.M3')

# %%
cask_ending_corr.append(B1M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B1M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B1M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B1M1'] = B1M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B1M2'] = (B1M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B1M3'] = (B1M3['Percent_Correct'].tail(1).values[0])

# %%
acc.graph_cumulative_acc([B1M1, B1M2, B1M3], 1)

# %% [markdown]
# ###  Bhv 4

# %%
B4M1 = acc.read_excel_by_sheet(sheet='B4.M1')
B4M2 = acc.read_excel_by_sheet(sheet='B4.M2')
B4M3 = acc.read_excel_by_sheet(sheet='B4.M3')
B4M4 = acc.read_excel_by_sheet(sheet='B4.M4')

# %%
cask_ending_corr.append(B4M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B4M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B4M3['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B4M4['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B4M1'] = B4M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B4M2'] = (B4M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B4M3'] = (B4M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B4M4'] = (B4M4['Percent_Correct'].tail(1).values[0])

# %% [markdown]
# ### Learning Rate for Bhv 4

# %%
acc.graph_cumulative_acc([B4M1, B4M2, B4M3, B4M4], 4)

# %% [markdown]
# ###  Bhv 6

# %%
B6M1 = acc.read_excel_by_sheet(sheet='B6.M1')
B6M2 = acc.read_excel_by_sheet(sheet='B6.M2')
B6M3 = acc.read_excel_by_sheet(sheet='B6.M3')
B6M4 = acc.read_excel_by_sheet(sheet='B6.M4')

# %%
cask_ending_corr.append(B6M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B6M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B6M3['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B6M4['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B6M1'] = B6M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B6M2'] = (B6M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B6M3'] = (B6M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B6M4'] = (B6M4['Percent_Correct'].tail(1).values[0])

# %% [markdown]
# ### Learning Rate for Bhv 6

# %%
acc.graph_cumulative_acc([B6M1, B6M2, B6M3, B6M4], 6)

# %% [markdown]
# ###  Bhv 8

# %%
B8M1 = acc.read_excel_by_sheet(sheet='B8.M1')
B8M2 = acc.read_excel_by_sheet(sheet='B8.M2')
B8M3 = acc.read_excel_by_sheet(sheet='B8.M3')

# %%
cask_ending_corr.append(B8M1['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B8M2['Percent_Correct'].tail(1).values[0])
cask_ending_corr.append(B8M3['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B8M1'] = B8M1['Percent_Correct'].tail(1).values[0]
cask_dict_corr['B8M2'] = (B8M2['Percent_Correct'].tail(1).values[0])
cask_dict_corr['B8M3'] = (B8M3['Percent_Correct'].tail(1).values[0])

# %%
import csv

# %%
csv_file = '/output/control_accuracy.csv'

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(['Mice', 'Accuracy'])

    for key, value in ctrl_dict_corr.items():
        writer.writerow([key, value])

# %%
csv_file = '/output/cask_accuracy.csv'

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(['Mice', 'Accuracy'])

    for key, value in cask_dict_corr.items():
        writer.writerow([key, value])

# %% [markdown]
# ### Learning Rate for Bhv 8

# %%
acc.graph_cumulative_acc([B8M1, B8M2, B8M3], 8)

# %% [markdown]
# ### Accuracy Grouped by 1 hour

# %% [markdown]
# ### Control Group

# %%
sheet = paths.fr1_ctrl_sheet[0]
data,_ = acc.instant_acc(sheet)
acc.time_high_acc(data)[0]
# Out:
# Timestamp('2023-04-01 14:00:00')

# %%
ctrl_times = []

for each in paths.fr1_ctrl_sheet:
    data, info = acc.instant_acc(sheet=each)
    stamp, hrs = acc.time_high_acc(data)
    ctrl_times.append(hrs)
    acc.graph_instant_acc(data, info[0], info[1], stamp)

# %% [markdown]
# ### CASK Group

# %%
cask_times = []

for each in paths.fr1_cask_sheet:
    data, info = acc.instant_acc(sheet=each)
    stamp, hrs = acc.time_high_acc(data)
    cask_times.append(hrs)
    acc.graph_instant_acc(data, info[0], info[1], stamp)

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Time need to reach 80% for 2 cont. hours

# %%
print(ctrl_times)
print(cask_times)
# Out:
# [5.0, 6.0, 16.0, 14.0, 20.0, 7.0, 6.0, 13.0, 2.0, 5.0, 3.0]
# [3.0, 2.0, 3.0, 3.0, 5.0, 3.0, 11.0, 6.0, 0.0, 13.0, 3.0]

# %%
# remove outliers (1 minimum and 1 maximum)
ctrl_times.remove(max(ctrl_times))
cask_times.remove(max(cask_times))
ctrl_times.remove(min(ctrl_times))
cask_times.remove(min(cask_times))

# %%
invs.perform_T_test(ctrl_times, cask_times)
# Out:
# P Value is  0.04284005335961936
# There is a significant difference between the two groups.

# %% [markdown]
# #### Ctrl/Cask Ending Correct Rate

# %%
invs.perform_T_test(ctrl_ending_corr, cask_ending_corr)
# Out:
# P Value is  0.0064146427421453815
# There is a significant difference between the two groups.

# %%
invs.MannWhitneyUTest(ctrl_ending_corr, cask_ending_corr)
# Out:
# U Statistic: 43.0
# P-value: 0.012274648109661161
# There is a significant difference between the two groups.

# %%
ctrl_mean = np.mean(ctrl_ending_corr)
cask_mean = np.mean(cask_ending_corr)
ctrl_err = np.std(ctrl_ending_corr) / np.sqrt(len(ctrl_ending_corr))
cask_err = np.std(cask_ending_corr) / np.sqrt(len(cask_ending_corr))
groups = ['Control', 'CASK']

# %%
x = np.arange(len(groups))
width = 0.4

# %%
# Create the bar plot for averages
plt.figure(figsize=(7, 7))

plt.bar([1, 2], [ctrl_mean, cask_mean], yerr=[ctrl_err, cask_err], capsize=12, tick_label=groups, 
        width=width, color=['lightblue', 'yellow'], alpha=0.8, zorder=1, label=['Control', 'CASK'])

x1 = [1] * len(ctrl_ending_corr)
x2 = [2] * len(cask_ending_corr)
plt.scatter(x1, ctrl_ending_corr, marker='o', color='blue', zorder=2) 
plt.scatter(x2, cask_ending_corr, marker='x', color='orange', zorder=2)

plt.xlabel('Groups', fontsize=14)
plt.ylabel('Correct Rate (%)', fontsize=14)
plt.title('Average Correct Rate of Control and CASK Groups in FR1', fontsize=16)

plt.legend()
plt.show()

# %% [markdown]
# * Overall, mice in CASK Group has higher correct rate at the end of the session
# May do further analysis/stats test
