# %% [markdown]
# ## Investigation On Intervals and Determine whether it's meal

# %%
import meals as ml
path = 'behavior data integrated/Adjusted FED3 Data.xlsx'
a = 5

# %% [markdown]
# ## Control Group

# %% [markdown]
# ### Bhv 5

# %%
data = ml.process_sheet(path, 'B5.M1')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)

# %%
data = ml.process_sheet(path, 'B5.M2')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)

# %%
data = ml.process_sheet(path, 'B5.M3')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)

# %%
data = ml.process_sheet(path, 'B5.M4')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)

# %%
data = ml.process_sheet(path, 'B7.M2')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)

# %%
data = ml.process_sheet(path, 'B7.M3')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)

# %%
data = ml.process_sheet(path, 'B7.M4')
meal = ml.find_meals(data)
ml.graphing_cum_count(data, meal)
group = ml.find_pellet_frequency(data)
ml.graph_pellet_frequency(group)
