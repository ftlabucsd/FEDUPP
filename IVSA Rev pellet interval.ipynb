# %%
from intervals import graph_pellet_interval, clean_and_interval, perform_T_test, MannWhitneyUTest
import paths

# %%
for file in paths.reversal_ivsa_ctrl:
    graph_pellet_interval(file)

# %%
for file in paths.reversal_ivsa_exp:
    graph_pellet_interval(file)
