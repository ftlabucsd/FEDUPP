# %%
from accuracy import count_error_rate, draw_left_right_error, draw_mean_error_rate
import paths
import intervals as invs
from preprocessing import read_csv_clean

# %%
# index 0 is control, index 1 is experiment
left_rate = [[], []]
right_rate = [[], []]
ctrl = []
exp = []

# %%
for path in paths.reversal_ivsa_ctrl:
    print(path)
    try:
        df = read_csv_clean(path=path)
        rateL, rateR, overall = count_error_rate(df, overall_accuracy=True)
        left_rate[0].append(rateL)
        right_rate[0].append(rateR)
        ctrl.append(overall)
    except:
        pass

for path in paths.reversal_ivsa_exp:
    print(path)
    df = read_csv_clean(path=path)
    rateL, rateR, overall = count_error_rate(df, overall_accuracy=True)
    left_rate[1].append(rateL)
    right_rate[1].append(rateR)
    exp.append(overall)
# Out:
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/43 - device found off position but accessible/Reversal/FED000_010000_02.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/52 - device found against the wall/Reversal/FED000_032124_15.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/50/Reversal/FED000_032124_03.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/41/Reversal/FED000_032124_01.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/53/Reversal/FED000_032124_02.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/44/Reversal/FED000_032124_03.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/51/Reversal/FED000_032124_04.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/45/Reversal/FED000_032124_13.CSV
# /home/ftlab/Desktop/For_Andy/FED3-data/preprocessing.py:63: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/54/Reversal/FED000_032124_07.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/55/Reversal/FED000_032124_04.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/46/Reversal/FED000_032224_03.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/47/Reversal/FED000_032124_02.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/57/Reversal/FED000_032124_03.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/49/Reversal/FED000_032124_05.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/CD1 IVSA/56/Reversal/FED000_032124_02.CSV

# %%
draw_left_right_error(left_rate, right_rate, groups=['control', 'PICA'], verbose=True)
# Out:
# Left Average: [0.47857142857142854, 0.4071428571428571]
# Right Average: [0.40714285714285714, 0.45999999999999996]
# Left Standard Deviation: [0.05239177377397785, 0.0236758150374401]
# Right Standard Deviation: [0.03106937595847363, 0.03927922024247863]

# %%
draw_mean_error_rate(ctrl, exp, dpi=120, groups=['Control', 'PICA'], bar_width=0.2, err_width=16, verbose=True)
# Out:
# Control Size: 7
# PICA Size: 7
# Control Average: 0.4585714285714286
# PICA Average: 0.43999999999999995
# Control Standard Deviation: 0.09616454152970857
# PICA Standard Deviation: 0.03958114029012638
