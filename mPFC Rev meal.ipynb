# %%
import meals as ml
import tools as tl
import paths
from preprocessing import read_csv_clean, prep_pellet_count

# %%
fent_meal_count = []
for path in paths.reversal_fent:
    test = read_csv_clean(path)
    avg = round(len(ml.find_meals(test)) / ml.experiment_duration(test), 2)
    fent_meal_count.append(avg)
fent_meal_count
# Out:
# [20.11, 0.0, 17.45, 40.51, 15.46]

# %%
veh_meal_count = []
for path in paths.reversal_veh:
    test = read_csv_clean(path)
    avg = round(len(ml.find_meals(test)) / ml.experiment_duration(test), 2)
    veh_meal_count.append(avg)
veh_meal_count
# Out:
# [21.29, 28.96, 19.51, 11.64, 12.74]

# %%
path = paths.reversal_veh[1]
path
# Out:
# '/home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M6.CSV'

# %%
path = path[:-4]+'_1.csv'

# %%
path
# Out:
# '/home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M6_1_1.csv'

# %%
prep_pellet_count(path)

# %%
data = read_csv_clean(path)
meal = ml.find_meals(data)
group = ml.pellet_flip(data)
num = tl.get_bhv_num(path, group=False)
ml.graph_pellet_frequency(group, None, num)
ml.graphing_cum_count(data, meal, None, num, flip=True)

# %%
fent_avg_pellet = [] # pellet per hour
fent_dark_meals = [] # percentage of meals in inactive/dark phase
for path in paths.reversal_fent:
    print(path)
    data = read_csv_clean(path)
    meal = ml.find_meals(data)
    group = ml.pellet_flip(data)
    num = tl.get_bhv_num(path, group=False)
    fent_avg_pellet.append(ml.average_pellet(group))
    fent_dark_meals.append(ml.active_meal(meal))
    ml.graph_pellet_frequency(group, None, num)
    ml.graphing_cum_count(data, meal, None, num, flip=True)
# Out:
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Fentanyl Tx/Reversal/M1.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Fentanyl Tx/Reversal/M2.CSV
# /home/ftlab/Desktop/For_Andy/FED3-data/meals.py:23: RuntimeWarning: divide by zero encountered in divide
#   return round(total_pellet / total_hr, 3)
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Fentanyl Tx/Reversal/M3.csv
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Fentanyl Tx/Reversal/M4.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Fentanyl Tx/Reversal/M5.CSV

# %%
veh_avg_pellet = [] # pellet per hour
veh_dark_meals = [] # percentage of meals in inactive/dark phase
for path in paths.reversal_veh:
    print(path)
    data = read_csv_clean(path)
    meal = ml.find_meals(data)
    group = ml.pellet_flip(data)
    num = tl.get_bhv_num(path, group=False)
    veh_avg_pellet.append(ml.average_pellet(group))
    veh_dark_meals.append(ml.active_meal(meal))
    ml.graph_pellet_frequency(group, None, num)
    ml.graphing_cum_count(data, meal, None, num, flip=True)
# Out:
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M10.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M6.csv
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M7.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M8.CSV
# /home/ftlab/Desktop/For_Andy/behavior data integrated/mPFC/Vehicle Tx/Reversal/M9.CSV
