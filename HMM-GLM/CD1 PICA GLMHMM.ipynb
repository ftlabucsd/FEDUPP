# %%
import numpy.random as npr
import util as uls
import warnings
import paths

warnings.filterwarnings('ignore') 
npr.seed(0)

# %%
cask = paths.reversal_ivsa_exp
num_states = 3
obs_dim = 1
num_categories = 2
max_iter = 800
prev_trace = 6

# %%
file = cask[0]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CD1 IVSA/54/Reversal/FED000_032124_07.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7850287907869482; Accuracy in the model: 0.8138195777351248
# State 1 Percentage: 0.5566218809980806, ; Accuracy:, 0.7448275862068966
# State 2 Percentage: 0.28790786948176583, ; Accuracy:, 0.88
# State 3 Percentage: 0.15547024952015356, ; Accuracy:, 0.9382716049382716

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = cask[1]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CD1 IVSA/55/Reversal/FED000_032124_04.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6419213973799127; Accuracy in the model: 0.5960698689956332
# State 1 Percentage: 0.6069868995633187, ; Accuracy:, 0.539568345323741
# State 2 Percentage: 0.06331877729257641, ; Accuracy:, 0.6551724137931034
# State 3 Percentage: 0.3296943231441048, ; Accuracy:, 0.6887417218543046

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = cask[2]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CD1 IVSA/46/Reversal/FED000_032224_03.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7481203007518797; Accuracy in the model: 0.5902255639097744
# State 1 Percentage: 0.38721804511278196, ; Accuracy:, 0.5728155339805825
# State 2 Percentage: 0.4548872180451128, ; Accuracy:, 0.6694214876033058
# State 3 Percentage: 0.15789473684210525, ; Accuracy:, 0.40476190476190477

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = cask[3]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CD1 IVSA/47/Reversal/FED000_032124_02.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.773955773955774; Accuracy in the model: 0.7542997542997543
# State 1 Percentage: 0.43734643734643736, ; Accuracy:, 0.6573033707865169
# State 2 Percentage: 0.457002457002457, ; Accuracy:, 0.8655913978494624
# State 3 Percentage: 0.10565110565110565, ; Accuracy:, 0.6744186046511628

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = cask[4]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CD1 IVSA/57/Reversal/FED000_032124_03.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7896253602305475; Accuracy in the model: 0.7809798270893372
# State 1 Percentage: 0.10086455331412104, ; Accuracy:, 0.8
# State 2 Percentage: 0.3804034582132565, ; Accuracy:, 0.7121212121212122
# State 3 Percentage: 0.5187319884726225, ; Accuracy:, 0.8277777777777777

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = cask[5]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=3, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=4, meal=True, transition='recurrent')
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CD1 IVSA/49/Reversal/FED000_032124_05.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6275140788415124; Accuracy in the model: 0.6934835076427996
# State 1 Percentage: 0.5277554304102977, ; Accuracy:, 0.698170731707317
# State 2 Percentage: 0.33226065969428803, ; Accuracy:, 0.6755447941888619
# State 3 Percentage: 0.13998390989541432, ; Accuracy:, 0.7183908045977011

# %%
uls.graph_posterior_state_prob(model, X, y)
