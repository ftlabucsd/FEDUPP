# %% [markdown]
# # GLM-HMM in Curr_Active, meal and prev_reward

# %%
import numpy.random as npr
import matplotlib.pyplot as plt
import utils as uls
from sklearn.metrics import accuracy_score
import warnings
import paths

warnings.filterwarnings('ignore') 
npr.seed(0)

# %%
# [current active poke, previous choice, previous active poke, meal, previous reward]

feat = [True, False, False, True, True]

# %%
log, model, X, y = uls.model_training(
    path='../../behavior data integrated/Bhv 7 - Ctrl/M2/Contingency Flip/FED000_071823_00.CSV',
    num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6071428571428571
# State 1 Percentage: 0.4785714285714286 ; Accuracy: 0.26865671641791045
# State 2 Percentage: 0.29285714285714287 ; Accuracy: 0.8292682926829268
# State 3 Percentage: 0.22857142857142856 ; Accuracy: 0.25
# Overall Accuracy in Model: 0.42857142857142855

# %% [markdown]
# ### Control Group

# %%
B5M1 = "../" + paths.contigency_flip_ctrl[0]
print(B5M1)
log, model, X, y = uls.model_training(B5M1, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M1/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.5842696629213483
# State 1 Percentage: 0.08426966292134831 ; Accuracy: 0.26666666666666666
# State 2 Percentage: 0.6853932584269663 ; Accuracy: 0.7213114754098361
# State 3 Percentage: 0.2303370786516854 ; Accuracy: 0.6829268292682927
# Overall Accuracy in Model: 0.6741573033707865

# %%
B5M2 = "../" + paths.contigency_flip_ctrl[1]
print(B5M2)
log, model, X, y = uls.model_training(B5M2, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M2/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.5529411764705883
# State 1 Percentage: 0.041176470588235294 ; Accuracy: 0.2857142857142857
# State 2 Percentage: 0.7411764705882353 ; Accuracy: 0.6984126984126984
# State 3 Percentage: 0.21764705882352942 ; Accuracy: 0.972972972972973
# Overall Accuracy in Model: 0.7411764705882353

# %%
B5M3 = "../" + paths.contigency_flip_ctrl[2]
print(B5M3)
log, model, X, y = uls.model_training(B5M3, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M3/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.7428571428571429
# State 1 Percentage: 0.12857142857142856 ; Accuracy: 0.4444444444444444
# State 2 Percentage: 0.45 ; Accuracy: 0.8095238095238095
# State 3 Percentage: 0.42142857142857143 ; Accuracy: 0.6271186440677966
# Overall Accuracy in Model: 0.6857142857142857

# %%
B5M4 = "../" + paths.contigency_flip_ctrl[3]
print(B5M4)
log, model, X, y = uls.model_training(B5M4, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M4/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.7459016393442623
# State 1 Percentage: 0.6475409836065574 ; Accuracy: 0.810126582278481
# State 2 Percentage: 0.27049180327868855 ; Accuracy: 0.6666666666666666
# State 3 Percentage: 0.08196721311475409 ; Accuracy: 0.4
# Overall Accuracy in Model: 0.7377049180327869

# %%
B7M2 = "../" + paths.contigency_flip_ctrl[4]
print(B7M2)
log, model, X, y = uls.model_training(B7M2, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 7 - Ctrl/M2/Contingency Flip/FED000_071823_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.5571428571428572
# State 1 Percentage: 0.21428571428571427 ; Accuracy: 0.7333333333333333
# State 2 Percentage: 0.08571428571428572 ; Accuracy: 0.4166666666666667
# State 3 Percentage: 0.7 ; Accuracy: 0.42857142857142855
# Overall Accuracy in Model: 0.4928571428571429

# %%
B7M4 = "../" + paths.contigency_flip_ctrl[5]
print(B7M4)
log, model, X, y = uls.model_training(B7M4, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 7 - Ctrl/M4/Contingency Flip/FED000_071823_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.5914634146341463
# State 1 Percentage: 0.42073170731707316 ; Accuracy: 0.6376811594202898
# State 2 Percentage: 0.2804878048780488 ; Accuracy: 0.34782608695652173
# State 3 Percentage: 0.29878048780487804 ; Accuracy: 0.5510204081632653
# Overall Accuracy in Model: 0.5304878048780488

# %% [markdown]
# ### Cask Group

# %%
B6M1 = "../" + paths.contigency_flip_cask[0]
print(B6M1)
log, model, X, y = uls.model_training(B6M1, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 6 - Cask/M1/Contingency Flip/FED000_071123_06.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.5984251968503937
# State 1 Percentage: 0.2283464566929134 ; Accuracy: 0.1724137931034483
# State 2 Percentage: 0.5511811023622047 ; Accuracy: 0.7428571428571429
# State 3 Percentage: 0.2204724409448819 ; Accuracy: 1.0
# Overall Accuracy in Model: 0.6692913385826772

# %%
B6M2 = "../" + paths.contigency_flip_cask[1]
print(B6M2)
log, model, X, y = uls.model_training(B6M2, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 6 - Cask/M2/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6
# State 1 Percentage: 0.38620689655172413 ; Accuracy: 0.4107142857142857
# State 2 Percentage: 0.43448275862068964 ; Accuracy: 0.7142857142857143
# State 3 Percentage: 0.1793103448275862 ; Accuracy: 0.2692307692307692
# Overall Accuracy in Model: 0.5172413793103449

# %%
B6M3 = "../" + paths.contigency_flip_cask[2]
print(B6M3)
log, model, X, y = uls.model_training(B6M3, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 6 - Cask/M3/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.7552447552447552
# State 1 Percentage: 0.5804195804195804 ; Accuracy: 0.4457831325301205
# State 2 Percentage: 0.16083916083916083 ; Accuracy: 0.5652173913043478
# State 3 Percentage: 0.25874125874125875 ; Accuracy: 0.7297297297297297
# Overall Accuracy in Model: 0.5384615384615384

# %%
B6M4 = "../" + paths.contigency_flip_cask[3]
print(B6M4)
log, model, X, y = uls.model_training(B6M4, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 6 - Cask/M4/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.7538461538461538
# State 1 Percentage: 0.1076923076923077 ; Accuracy: 0.7619047619047619
# State 2 Percentage: 0.5435897435897435 ; Accuracy: 0.6792452830188679
# State 3 Percentage: 0.3487179487179487 ; Accuracy: 0.7058823529411765
# Overall Accuracy in Model: 0.6974358974358974

# %%
B8M1 = "../" + paths.contigency_flip_cask[4]
print(B8M1)
log, model, X, y = uls.model_training(B8M1, num_states=3, obs_dim=1, num_categories=2, max_iter=800, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 8 - Cask/M1/Contingency Flip/FED000_071823_00.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.56282722513089
# State 1 Percentage: 0.4319371727748691 ; Accuracy: 0.6727272727272727
# State 2 Percentage: 0.4031413612565445 ; Accuracy: 0.5844155844155844
# State 3 Percentage: 0.1649214659685864 ; Accuracy: 0.4126984126984127
# Overall Accuracy in Model: 0.5942408376963351

# %%
B8M2 = "../" + paths.contigency_flip_cask[5]
print(B8M2)
log, model, X, y = uls.model_training(B8M2, num_states=3, obs_dim=1, num_categories=2, max_iter=800, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 8 - Cask/M2/Contingency Flip/FED000_071823_00.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.5982905982905983
# State 1 Percentage: 0.3974358974358974 ; Accuracy: 0.5913978494623656
# State 2 Percentage: 0.48717948717948717 ; Accuracy: 0.37719298245614036
# State 3 Percentage: 0.11538461538461539 ; Accuracy: 0.4074074074074074
# Overall Accuracy in Model: 0.4658119658119658

# %%
B9M1 = "../" + paths.contigency_flip_cask[6]
print(B9M1)
log, model, X, y = uls.model_training(B9M1, num_states=3, obs_dim=1, num_categories=2, max_iter=800, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 8 - Cask/M3/Contingency Flip/FED000_071823_00.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6470588235294118
# State 1 Percentage: 0.5294117647058824 ; Accuracy: 0.7160493827160493
# State 2 Percentage: 0.3464052287581699 ; Accuracy: 0.5283018867924528
# State 3 Percentage: 0.12418300653594772 ; Accuracy: 0.10526315789473684
# Overall Accuracy in Model: 0.5751633986928104

# %%
B9M2 = "../" + paths.contigency_flip_cask[7]
print(B9M2)
log, model, X, y = uls.model_training(B9M2, num_states=3, obs_dim=1, num_categories=2, max_iter=800, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 9 - Cask/M1/Contingency Flip/FED000_090223_10.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6076555023923444
# State 1 Percentage: 0.33014354066985646 ; Accuracy: 0.42028985507246375
# State 2 Percentage: 0.3349282296650718 ; Accuracy: 0.6285714285714286
# State 3 Percentage: 0.3349282296650718 ; Accuracy: 0.7714285714285715
# Overall Accuracy in Model: 0.6076555023923444
