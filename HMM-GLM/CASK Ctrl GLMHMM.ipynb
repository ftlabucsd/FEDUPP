# %% [markdown]
# ## GLM-HMM in CASK Experiment for Control Group

# %%
import numpy.random as npr
import util as uls
import warnings
import paths

warnings.filterwarnings('ignore') 
npr.seed(0)

# %%
ctrl = paths.contigency_flip_ctrl
cask = paths.contigency_flip_cask
num_states = 3
obs_dim = 1
num_categories = 2
max_iter = 800
prev_trace = 6

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_cask[0],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)

# %%
uls.graph_posterior_state_prob(model, X, y)

# %% [markdown]
# ### Control Group

# %%
B5M1 = ctrl[0]
print(B5M1)
log, model, X, y, feat = uls.model_training(path=B5M1, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M1.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6713286713286714; Accuracy in the model: 0.655011655011655
# State 1 Percentage: 0.6876456876456877, ; Accuracy:, 0.711864406779661
# State 2 Percentage: 0.22843822843822845, ; Accuracy:, 0.5918367346938775
# State 3 Percentage: 0.08391608391608392, ; Accuracy:, 0.3611111111111111

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[1]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M2.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6834733893557423; Accuracy in the model: 0.6274509803921569
# State 1 Percentage: 0.22128851540616246, ; Accuracy:, 0.6835443037974683
# State 2 Percentage: 0.2913165266106443, ; Accuracy:, 0.7115384615384616
# State 3 Percentage: 0.48739495798319327, ; Accuracy:, 0.5517241379310345

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[2]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M3.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.707641196013289; Accuracy in the model: 0.6810631229235881
# State 1 Percentage: 0.10299003322259136, ; Accuracy:, 0.4838709677419355
# State 2 Percentage: 0.292358803986711, ; Accuracy:, 0.5454545454545454
# State 3 Percentage: 0.6046511627906976, ; Accuracy:, 0.7802197802197802

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[3]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M4.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7341772151898734; Accuracy in the model: 0.7518987341772152
# State 1 Percentage: 0.7012658227848101, ; Accuracy:, 0.7581227436823105
# State 2 Percentage: 0.13924050632911392, ; Accuracy:, 0.5454545454545454
# State 3 Percentage: 0.15949367088607594, ; Accuracy:, 0.9047619047619048

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[4]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M2.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7582089552238805; Accuracy in the model: 0.6597014925373135
# State 1 Percentage: 0.14925373134328357, ; Accuracy:, 0.58
# State 2 Percentage: 0.6029850746268657, ; Accuracy:, 0.6188118811881188
# State 3 Percentage: 0.24776119402985075, ; Accuracy:, 0.8072289156626506

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[5]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M4.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7058823529411765; Accuracy in the model: 0.6363636363636364
# State 1 Percentage: 0.5427807486631016, ; Accuracy:, 0.6206896551724138
# State 2 Percentage: 0.2700534759358289, ; Accuracy:, 0.6633663366336634
# State 3 Percentage: 0.18716577540106952, ; Accuracy:, 0.6428571428571429

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
paths.contigency_flip_ctrl
# Out:
# ['/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M1.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M2.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M3.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M4.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M2.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M4.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/C1M1_Final.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/C1M2_Final.CSV',
#  '/home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/C2M1_Final.CSV',
# ...

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_ctrl[6],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.5845896147403685; Accuracy in the model: 0.5695142378559463
# State 1 Percentage: 0.32830820770519265, ; Accuracy:, 0.6224489795918368
# State 2 Percentage: 0.5711892797319933, ; Accuracy:, 0.49266862170087977
# State 3 Percentage: 0.10050251256281408, ; Accuracy:, 0.8333333333333334

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_ctrl[7],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.5893333333333334; Accuracy in the model: 0.5946666666666667
# State 1 Percentage: 0.32, ; Accuracy:, 0.8
# State 2 Percentage: 0.2693333333333333, ; Accuracy:, 0.2871287128712871
# State 3 Percentage: 0.4106666666666667, ; Accuracy:, 0.6363636363636364

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_ctrl[8],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.610989010989011; Accuracy in the model: 0.6857142857142857
# State 1 Percentage: 0.8967032967032967, ; Accuracy:, 0.7181372549019608
# State 2 Percentage: 0.004395604395604396, ; Accuracy:, 0.0
# State 3 Percentage: 0.0989010989010989, ; Accuracy:, 0.4222222222222222

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_ctrl[9],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.5844504021447721; Accuracy in the model: 0.6434316353887399
# State 1 Percentage: 0.48525469168900803, ; Accuracy:, 0.6685082872928176
# State 2 Percentage: 0.1447721179624665, ; Accuracy:, 0.6111111111111112
# State 3 Percentage: 0.3699731903485255, ; Accuracy:, 0.6231884057971014

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_ctrl[10],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6082474226804123; Accuracy in the model: 0.6237113402061856
# State 1 Percentage: 0.6701030927835051, ; Accuracy:, 0.6192307692307693
# State 2 Percentage: 0.11855670103092783, ; Accuracy:, 0.7608695652173914
# State 3 Percentage: 0.211340206185567, ; Accuracy:, 0.5609756097560976

# %%
uls.graph_posterior_state_prob(model, X, y)
