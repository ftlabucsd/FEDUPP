# %% [markdown]
# ## GLM-HMM in CASK Experiment for Control Group

# %%
import numpy.random as npr
import util as uls
import warnings
import paths

warnings.filterwarnings('ignore') 
npr.seed(0)

# %%
ctrl = paths.contigency_flip_ctrl
cask = paths.contigency_flip_cask
num_states = 3
obs_dim = 1
num_categories = 2
max_iter = 800
prev_trace = 6

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_cask[-3],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=6, meal=True)

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)

# %%
uls.graph_posterior_state_prob(model, X, y)

# %% [markdown]
# ### Control Group

# %%
B5M1 = ctrl[0]
print(B5M1)
log, model, X, y, feat = uls.model_training(path=B5M1, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M1.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6596736596736597; Accuracy in the model: 0.6247086247086248
# State 1 Percentage: 0.08391608391608392, ; Accuracy:, 0.6944444444444444
# State 2 Percentage: 0.1048951048951049, ; Accuracy:, 0.5777777777777777
# State 3 Percentage: 0.8111888111888111, ; Accuracy:, 0.6235632183908046

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[1]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M2.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6694677871148459; Accuracy in the model: 0.6078431372549019
# State 1 Percentage: 0.5126050420168067, ; Accuracy:, 0.5628415300546448
# State 2 Percentage: 0.33613445378151263, ; Accuracy:, 0.675
# State 3 Percentage: 0.15126050420168066, ; Accuracy:, 0.6111111111111112

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[2]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M3.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7508305647840532; Accuracy in the model: 0.6843853820598007
# State 1 Percentage: 0.6644518272425249, ; Accuracy:, 0.72
# State 2 Percentage: 0.14285714285714285, ; Accuracy:, 0.6744186046511628
# State 3 Percentage: 0.19269102990033224, ; Accuracy:, 0.5689655172413793

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[3]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M4.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7569620253164557; Accuracy in the model: 0.8
# State 1 Percentage: 0.13670886075949368, ; Accuracy:, 0.6296296296296297
# State 2 Percentage: 0.5113924050632911, ; Accuracy:, 0.8564356435643564
# State 3 Percentage: 0.3518987341772152, ; Accuracy:, 0.7841726618705036

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[4]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M2.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7104477611940299; Accuracy in the model: 0.6716417910447762
# State 1 Percentage: 0.1880597014925373, ; Accuracy:, 0.5873015873015873
# State 2 Percentage: 0.6835820895522388, ; Accuracy:, 0.7554585152838428
# State 3 Percentage: 0.12835820895522387, ; Accuracy:, 0.3488372093023256

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[5]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M4.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7299465240641712; Accuracy in the model: 0.6443850267379679
# State 1 Percentage: 0.4037433155080214, ; Accuracy:, 0.7483443708609272
# State 2 Percentage: 0.339572192513369, ; Accuracy:, 0.7480314960629921
# State 3 Percentage: 0.25668449197860965, ; Accuracy:, 0.34375

# %%
uls.graph_posterior_state_prob(model, X, y)
