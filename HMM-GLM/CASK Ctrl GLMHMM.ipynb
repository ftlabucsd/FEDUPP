# %% [markdown]
# ## GLM-HMM in CASK Experiment for Control Group

# %%
import numpy.random as npr
import util as uls
import warnings
import paths

warnings.filterwarnings('ignore') 
npr.seed(0)

# %%
ctrl = paths.contigency_flip_ctrl
cask = paths.contigency_flip_cask
num_states = 3
obs_dim = 1
num_categories = 2
max_iter = 800
prev_trace = 6

# %%
log, model, X, y, feat = uls.model_training(
    path=paths.contigency_flip_cask[0],
    num_states=3, obs_dim=1, num_categories=2, max_iter=800, prev_trace=3, meal=True)

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)

# %%
uls.graph_posterior_state_prob(model, X, y)

# %% [markdown]
# ### Control Group

# %%
B5M1 = ctrl[0]
print(B5M1)
log, model, X, y, feat = uls.model_training(path=B5M1, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M1.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.6433566433566433; Accuracy in the model: 0.5617715617715617
# State 1 Percentage: 0.5664335664335665, ; Accuracy:, 0.5679012345679012
# State 2 Percentage: 0.2191142191142191, ; Accuracy:, 0.7446808510638298
# State 3 Percentage: 0.21445221445221446, ; Accuracy:, 0.358695652173913

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[1]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M2.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7030812324929971; Accuracy in the model: 0.6694677871148459
# State 1 Percentage: 0.2605042016806723, ; Accuracy:, 0.7526881720430108
# State 2 Percentage: 0.1400560224089636, ; Accuracy:, 0.74
# State 3 Percentage: 0.5994397759103641, ; Accuracy:, 0.616822429906542

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[2]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M3.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7906976744186046; Accuracy in the model: 0.7574750830564784
# State 1 Percentage: 0.292358803986711, ; Accuracy:, 0.7272727272727273
# State 2 Percentage: 0.4186046511627907, ; Accuracy:, 0.8412698412698413
# State 3 Percentage: 0.28903654485049834, ; Accuracy:, 0.6666666666666666

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[3]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B5M4.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7417721518987341; Accuracy in the model: 0.7341772151898734
# State 1 Percentage: 0.12151898734177215, ; Accuracy:, 0.7083333333333334
# State 2 Percentage: 0.6354430379746835, ; Accuracy:, 0.7729083665338645
# State 3 Percentage: 0.2430379746835443, ; Accuracy:, 0.6458333333333334

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[4]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M2.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.746268656716418; Accuracy in the model: 0.6716417910447762
# State 1 Percentage: 0.2746268656716418, ; Accuracy:, 0.782608695652174
# State 2 Percentage: 0.408955223880597, ; Accuracy:, 0.635036496350365
# State 3 Percentage: 0.3164179104477612, ; Accuracy:, 0.6226415094339622

# %%
uls.graph_posterior_state_prob(model, X, y)

# %%
file = ctrl[5]
print(file)
log, model, X, y, feat = uls.model_training(path=file, num_states=num_states, obs_dim=obs_dim,
                                            num_categories=num_categories, max_iter=max_iter, 
                                            prev_trace=prev_trace, meal=True)
# Out:
# /home/ftlab/Desktop/For_Andy/FED3-data/behavior data integrated/CASK/reversal/ctrl/B7M4.CSV
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Prediction: 0.7593582887700535; Accuracy in the model: 0.6524064171122995
# State 1 Percentage: 0.17379679144385027, ; Accuracy:, 0.5076923076923077
# State 2 Percentage: 0.43315508021390375, ; Accuracy:, 0.7160493827160493
# State 3 Percentage: 0.393048128342246, ; Accuracy:, 0.6462585034013606

# %%
uls.graph_posterior_state_prob(model, X, y)
