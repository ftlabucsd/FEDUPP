# %% [markdown]
# ## GLM-HMM in

# %%
import numpy.random as npr
import matplotlib.pyplot as plt
import utils as uls
from sklearn.metrics import accuracy_score
import warnings
import paths

warnings.filterwarnings('ignore') 
npr.seed(0)

# %%
# [current active poke, previous choice, previous active poke, meal, previous reward]

feat = [True, True, False, False, True]

# %%
log, model, X, y = uls.model_training(
    path='../../behavior data integrated/Bhv 7 - Ctrl/M2/Contingency Flip/FED000_071823_00.CSV',
    num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6928571428571428
# State 1 Percentage: 0.6 ; Accuracy: 0.6190476190476191
# State 2 Percentage: 0.12857142857142856 ; Accuracy: 0.3888888888888889
# State 3 Percentage: 0.2714285714285714 ; Accuracy: 0.5526315789473685
# Overall Accuracy in Model: 0.5714285714285714

# %% [markdown]
# ### Control Group

# %%
B5M1 = "../" + paths.contigency_flip_ctrl[0]
print(B5M1)
log, model, X, y = uls.model_training(B5M1, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M1/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6235955056179775
# State 1 Percentage: 0.20786516853932585 ; Accuracy: 0.7297297297297297
# State 2 Percentage: 0.34269662921348315 ; Accuracy: 0.8524590163934426
# State 3 Percentage: 0.449438202247191 ; Accuracy: 0.325
# Overall Accuracy in Model: 0.5898876404494382

# %%
B5M2 = "../" + paths.contigency_flip_ctrl[1]
print(B5M2)
log, model, X, y = uls.model_training(B5M2, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M2/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.6058823529411764
# State 1 Percentage: 0.5941176470588235 ; Accuracy: 0.42574257425742573
# State 2 Percentage: 0.07647058823529412 ; Accuracy: 0.07692307692307693
# State 3 Percentage: 0.32941176470588235 ; Accuracy: 0.875
# Overall Accuracy in Model: 0.5470588235294118

# %%
B5M3 = "../" + paths.contigency_flip_ctrl[2]
print(B5M3)
log, model, X, y = uls.model_training(B5M3, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M3/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.7214285714285714
# State 1 Percentage: 0.5071428571428571 ; Accuracy: 0.6197183098591549
# State 2 Percentage: 0.25 ; Accuracy: 0.7714285714285715
# State 3 Percentage: 0.24285714285714285 ; Accuracy: 0.8235294117647058
# Overall Accuracy in Model: 0.7071428571428572

# %%
B5M4 = "../" + paths.contigency_flip_ctrl[3]
print(B5M4)
log, model, X, y = uls.model_training(B5M4, num_states=3, obs_dim=1, num_categories=2, max_iter=500, feat=feat)
# Out:
# ../../behavior data integrated/Bhv 5 - Ctrl/M4/Contingency Flip/FED000_071123_00.CSV
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
uls.graph_model_parameters(model, log, feat)

# %%
uls.display_fitting_results(model, X, y)
# Out:
# Accuracy of Predicting Mice Behavior: 0.7213114754098361
# State 1 Percentage: 0.6721311475409836 ; Accuracy: 0.7560975609756098
# State 2 Percentage: 0.07377049180327869 ; Accuracy: 0.8888888888888888
# State 3 Percentage: 0.2540983606557377 ; Accuracy: 0.6774193548387096
# Overall Accuracy in Model: 0.7459016393442623
